# %%
# !pip install pandas

# %%
import pandas as pd

# %%
#Series
import pandas as pd
data=[1,2,3,4,5]
series=pd.Series(data)
print(series)
# Out:
# 0    1
# 1    2
# 2    3
# 3    4
# 4    5
# dtype: int64

# %%
data={"a":1,"b":2,"c":3}
series_ddict=pd.Series(data)
print(series_ddict)
# Out:
# a    1
# b    2
# c    3
# dtype: int64

# %%
## To mention the index of our own 
data=[10,20,30]
data_index=['a','b','c']
series_data_index=pd.Series(data,index=data_index)
print(series_data_index)
# Out:
# a    10
# b    20
# c    30
# dtype: int64

# %%
#dataframe
import pandas as pd
data={
    'Name':['Karan','Tanvi','Mehta'],
    'Age':[22,22,65],
    'City':['Mumbai','Mulund','Gujarat']

}
df=pd.DataFrame(data)
print(df)
# Out:
#     Name  Age     City
# 0  Karan   22   Mumbai
# 1  Tanvi   22   Mulund
# 2  Mehta   65  Gujarat

# %%
data=pd.read_csv('data.csv')
data.head(5)
# Out:
#          Date Category  Value   Product  Sales Region
# 0  2023-01-01        A   28.0  Product1  754.0   East
# 1  2023-01-02        B   39.0  Product3  110.0  North
# 2  2023-01-03        C   32.0  Product2  398.0   East
# 3  2023-01-04        B    8.0  Product1  522.0   East
# 4  2023-01-05        B   26.0  Product3  869.0  North

# %%
data.tail(
    5)
# Out:
#           Date Category  Value   Product  Sales Region
# 45  2023-02-15        B   99.0  Product2  599.0   West
# 46  2023-02-16        B    6.0  Product1  938.0  South
# 47  2023-02-17        B   69.0  Product3  143.0   West
# 48  2023-02-18        C   65.0  Product3  182.0  North
# 49  2023-02-19        C   11.0  Product3  708.0  North

# %%
df['Name']
# Out:
# 0    Karan
# 1    Tanvi
# 2    Mehta
# Name: Name, dtype: object

# %%
df.loc[0]#
# Out:
# Name     Karan
# Age         22
# City    Mumbai
# Name: 0, dtype: object

# %%
df.iloc[0][0]
# Out:
# C:\Users\karan\AppData\Local\Temp\ipykernel_13904\2900375399.py:1: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   df.iloc[0][0]
# 'Karan'

# %%
## Accessing a specified element using at
df.at[2,'Age']
# Out:
# 65

# %%
## Accesing elements using iat
df.iat[2,2]
# Out:
# 'Gujarat'

# %%
df
# Out:
#     Name  Age     City
# 0  Karan   22   Mumbai
# 1  Tanvi   22   Mulund
# 2  Mehta   65  Gujarat

# %%
## Data Manipulation w.r.t dataframes
df['Salary']=[50000,600000,5000]
df
# Out:
#     Name  Age     City  Salary
# 0  Karan   22   Mumbai   50000
# 1  Tanvi   22   Mulund  600000
# 2  Mehta   65  Gujarat    5000

# %%
df
# Out:
#     Name  Age     City  Salary
# 0  Karan   22   Mumbai   50000
# 1  Tanvi   22   Mulund  600000
# 2  Mehta   65  Gujarat    5000

# %%
df.drop('City',axis=1,inplace=True)

# %%
df
# Out:
#     Name  Age  Salary
# 0  Karan   22   50000
# 1  Tanvi   22  600000
# 2  Mehta   65    5000

# %%
data.dtypes()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[31], line 1
# ----> 1 data.dtypes()
#
# AttributeError: 'dict' object has no attribute 'dtypes'

# %%
data=pd.read_csv('data.csv')
data
# Out:
#           Date Category  Value   Product  Sales Region
# 0   2023-01-01        A   28.0  Product1  754.0   East
# 1   2023-01-02        B   39.0  Product3  110.0  North
# 2   2023-01-03        C   32.0  Product2  398.0   East
# 3   2023-01-04        B    8.0  Product1  522.0   East
# 4   2023-01-05        B   26.0  Product3  869.0  North
# 5   2023-01-06        B   54.0  Product3  192.0   West
# 6   2023-01-07        A   16.0  Product1  936.0   East
# 7   2023-01-08        C   89.0  Product1  488.0   West
# 8   2023-01-09        C   37.0  Product3  772.0   West
# 9   2023-01-10        A   22.0  Product2  834.0   West
# 10  2023-01-11        B    7.0  Product1  842.0  North
# 11  2023-01-12        B   60.0  Product2    NaN   West
# 12  2023-01-13        A   70.0  Product3  628.0  South
# 13  2023-01-14        A   69.0  Product1  423.0   East
# 14  2023-01-15        A   47.0  Product2  893.0   West
# 15  2023-01-16        C    NaN  Product1  895.0  North
# ...

# %%
data.dtypes
# Out:
# Date         object
# Category     object
# Value       float64
# Product      object
# Sales       float64
# Region       object
# dtype: object

# %%
##Statstical Summary
data.describe()
# Out:
#            Value       Sales
# count  47.000000   46.000000
# mean   51.744681  557.130435
# std    29.050532  274.598584
# min     2.000000  108.000000
# 25%    27.500000  339.000000
# 50%    54.000000  591.500000
# 75%    70.000000  767.500000
# max    99.000000  992.000000
